# %%
easy_install pip
# Out:
#   File "<ipython-input-6-f77d9449d0ca>", line 1
#     easy_install pip
#                    ^
# SyntaxError: invalid syntax

# %%
sudo easy_install pip
sudo pip install BeautifulSoup4
# Out:
#   File "<ipython-input-7-e7b1225f8945>", line 1
#     sudo easy_install pip
#                     ^
# SyntaxError: invalid syntax

# %%
sudo easy_install pip
# Out:
#   File "<ipython-input-8-397f82267856>", line 1
#     sudo easy_install pip
#                     ^
# SyntaxError: invalid syntax

# %%
from selenium import webdriver
from BeautifulSoup import BeautifulSoup
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-954acb5e1d39> in <module>
# ----> 1 from selenium import webdriver
#       2 from BeautifulSoup import BeautifulSoup
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'selenium'

# %%
import pandas as pd

# %%
from BeautifulSoup import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-c72758632477> in <module>
# ----> 1 from BeautifulSoup import BeautifulSoup
#
# ModuleNotFoundError: No module named 'BeautifulSoup'

# %%
pip install BeautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from BeautifulSoup4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-d3df29fa5ffa> in <module>
# ----> 1 from BeautifulSoup4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'BeautifulSoup4'

# %%
sudo pip install BeautifulSoup4
# Out:
#   File "<ipython-input-14-c48ccf62430c>", line 1
#     sudo pip install BeautifulSoup4
#            ^
# SyntaxError: invalid syntax

# %%
import pip

# %%
sudo pip install BeautifulSoup4
# Out:
#   File "<ipython-input-16-c48ccf62430c>", line 1
#     sudo pip install BeautifulSoup4
#            ^
# SyntaxError: invalid syntax

# %%
from bs4 import BeautifulSoup

# %%
python3 get-pip.py
# Out:
#   File "<ipython-input-18-661f669de063>", line 1
#     python3 get-pip.py
#               ^
# SyntaxError: invalid syntax

# %%
import urllib2 from bs4
# Out:
#   File "<ipython-input-19-0ac8ce7d3bee>", line 1
#     import urllib2 from bs4
#                       ^
# SyntaxError: invalid syntax

# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-846c1dbd158b> in <module>
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Mihlali\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# WARNING: AstropyDeprecationWarning: astropy.utils.compat.futures is now deprecated - use concurrent.futures instead [astropy.utils.compat.futures]
# C:\Users\Mihlali\AppData\Local\Continuum\anaconda3\lib\site-packages\nltk\twitter\__init__.py:22: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   "The twython library has not been installed. "
# DEBUG:pip._internal.vcs.versioncontrol:Registered VCS backend: bzr
# DEBUG:pip._internal.vcs.versioncontrol:Registered VCS backend: git
# ...

# %%
import urllib2
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-5bb13d7a180b> in <module>
# ----> 1 import urllib2
#       2 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
easy_install pip
# Out:
#   File "<ipython-input-23-f77d9449d0ca>", line 1
#     easy_install pip
#                    ^
# SyntaxError: invalid syntax

# %%
sudo easy_install pip
# Out:
#   File "<ipython-input-24-397f82267856>", line 1
#     sudo easy_install pip
#                     ^
# SyntaxError: invalid syntax

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
quote_page = 'https://www.pnp.co.za/pnpstorefront/pnp/en/specials'

# %%
page = urllib.urlopen(quote_page)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-d7dbc2578fec> in <module>
# ----> 1 page = urllib.urlopen(quote_page)
#
# NameError: name 'urllib' is not defined

# %%
page = urllib.request.urlopen(quote_page)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-cbaa35235816> in <module>
# ----> 1 page = urllib.request.urlopen(quote_page)
#
# NameError: name 'urllib' is not defined

# %%
from urllib import urlopen
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-bca34e26fa80> in <module>
# ----> 1 from urllib import urlopen
#       2 from bs4 import BeautifulSoup
#
# ImportError: cannot import name 'urlopen' from 'urllib' (C:\Users\Mihlali\AppData\Local\Continuum\anaconda3\lib\urllib\__init__.py)

# %%
page = urlopen(quote_page)

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
title_box = soup.find('div', attrs={'class': 'fed-pdp-product-details-title'})

# %%
print(title_box)
# Out:
# None

# %%
title = title_box.text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-515fa58d70b4> in <module>
# ----> 1 title = title_box.text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(page)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>
# 		Shop Specials Online | Pick n Pay Online Shopping | Pick n Pay Online Shopping</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
# <meta content="specials, shop specials" name="keywords"/>
# <meta content="Shop specials online and save! Get the latest deals at Pick n Pay." name="description"/>
# <meta content="index, follow" name="robots"/>
# <link href="/pnpstorefront/_ui/responsive/theme-blue/images/pnp-favicon.ico" media="all" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.pnp.co.za/pnpstorefront/specials" rel="canonical"/>
# <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic,800,800italic" rel="stylesheet" type="text/css">
# ...

# %%
title_box = soup.find('div', attrs={'class': 'item-name'})

# %%
title = title_box.text.strip()

# %%
print(title)
# Out:
# Nescafe Classic Coffee 200g

# %%
itemPrice = soup.find('div', attrs={'class': 'item-price'})

# %%
print(itemPrice)
# Out:
# <div class="item-price">
# <div class="currentPrice">
# 			R79<span>99</span></div>
# </div>

# %%
itemPrice = soup.find('div', attrs={'class': 'currentPrice hasSavings'})

# %%
currentPrice = itemPrice.text.strip()

# %%
print(itemPrice)
# Out:
# <div class="currentPrice hasSavings">
# 			R47<span>99</span></div>

# %%
currentPrice = itemPrice.text.strip()

# %%
print(currentPrice)
# Out:
# R4799

# %%
print(currentPrice[1:])
# Out:
# 4799

# %%
string_price = currentPrice[1:]

# %%
numeric_price = int(string_price)

# %%
print(numeric_price)
# Out:
# 4799

# %%
type(numeric_price)
# Out:
# int
